# %%
import os
import pandas as pd
import yaml

# from tsv2bedRMod import bid_mouse2bedRMod, bid_human2bedRMod, etam2bedRMod, csv2bedRMod
from tsv2bedRMod import csv2bedRMod

from helper import write_header
from helper import get_modification_color
from helper import parse_excel

# %% [markdown]
# ## columns that I need for data
#     chrom       'chrM'
#     chromStart  number
#     chromEnd
#     name        m1G or m22G - manually for each file
#     score       none given.
#     strand      strand
#     thickStart
#     thickEnd
#     itemRGB     figure it out
#     coverage    add ACTG
#     frequency   mu
#
# ## columns that I need for header
#     organism human
#     modification_type RNA
#     assembly GRCh37
#     annotation_source None
#     annotation_version None
#     sequencing_platform Illumina NovaSeq 6000
#     basecalling None
#     bioinformatics_workflow
#     experiment https://doi.org/10.1038/s41467-023-42832-z
#     external_source SRA:PRJNA623501
#     methods DAMM-seq
#     references pubmed_id:34253897
#     conversion_information the original "Score" column is normalized by dividing each value by the maximum value

# %%
def convert_damm_mt_tRNA():
    def score_func(mu_col):
        return int(float(mu_col) * 1000)
    def frequency_func(mu_col):
        return int(float(mu_col) * 100)
    keys = parse_excel("/home/annebusch/anne02/euf-data/damm-seq/GSE148202_DAMM-seq_mt-tRNA_AllMethyl.xlsx")
    for key in keys: 
        print(key)
        df = pd.read_excel("/home/annebusch/anne02/euf-data/damm-seq/GSE148202_DAMM-seq_mt-tRNA_AllMethyl.xlsx", sheet_name=key)
        empty_rows = df.isnull().all(axis=1)
        df_list = []
        if empty_rows.any():
            empty_row_index = df[df.isna().all(axis=1)].index[0]
            df_list.append(df.iloc[:empty_row_index])
            df_list.append(df.iloc[empty_row_index +1:])
        else: 
            df_list.append(df)
        for dfl in df_list:
            chrom = "MT"
            pos = dfl.iloc[0, 1]
            strand = dfl.iloc[1, 1]
            modification = dfl.iloc[0, 2]
            split_at = "N"
            if "A" in modification:
                split_at = "A"
            if "G" in modification:
                split_at = "G"
            if "C" in modification:
                split_at = "C"
            split_mod, _ = modification.split(split_at)
            modi = split_mod + split_at
            
            if dfl.shape[1] == 12:
                df_input_subset = dfl.iloc[1:12, 3:12]
                column_names = ["Input", "A", "C", "G", "T", "GT", "GC", "GA", "Mu"]
                df_input_subset.columns = column_names
            else:
                df_input_subset = dfl.iloc[1:12, 3:9]
                column_names = ["Input", "A", "C", "G", "T", "Mu"]
                df_input_subset.columns = column_names
                
            directory = "/home/annebusch/anne02/euf-data/damm-seq/"
            config_yaml = "/home/annebusch/anne02/euf-data/damm-seq/hela_config.yaml"
            for index, row in df_input_subset.iterrows():
                file = row.Input.replace(" ", "")
                coverage = int(row.A) + int(row.C) + int(row.G) + int(row["T"]) 
                frequency = int(float(row.Mu) * 100)
                score = int(float(row.Mu) * 1000)
                if os.path.isfile(directory+file+"DAMM-seq_mt-tRNA_AllMethyl.bedrmod"):
                    with open(directory+file+"DAMM-seq_mt-tRNA_AllMethyl.bedrmod", "a") as data:
                        data.write(f"{chrom}\t{pos}\t{pos+1}\t{modi}\t{score}\t{strand}\t{pos}\t{pos+1}\t{0,0,0}\t{coverage}\t{frequency}\n")   
                else:
                    with open(directory+file+"DAMM-seq_mt-tRNA_AllMethyl.bedrmod", "w") as data:
                        config = yaml.safe_load(open(config_yaml, "r"))
                        write_header(config, data)
                        data.write("#chrom\tchromStart\tchromEnd\tname\tscore\tstrand\tthickStart\tthickEnd\titemRgb\tcoverage\tfrequency\n")
                        data.write(f"{chrom}\t{pos}\t{pos+1}\t{modi}\t{score}\t{strand}\t{pos}\t{pos+1}\t{0,0,0}\t{coverage}\t{frequency}\n")

    
convert_damm_mt_tRNA()
# Out:
# Ile
# Arg
# Asp
# Lys
# Leu1(CUN)
# Trp
# His
# Phe
# Gly
# Val
# Thr
# Leu2(UUR)
# Ala
# Tyr
# Ser2(UCN)
# Cys
# Asn
# Gln
# Glu
# Pro

# %%
import re

# %%
def convert_damm_vivo_ds():
    def score_func(mu_col):
        return int(float(mu_col) * 1000)
    def frequency_func(mu_col):
        return int(float(mu_col) * 100)

    keys = parse_excel("/home/annebusch/anne02/euf-data/damm-seq/GSE148202_Misincorporation_in-vivo_dsRNA_AllMethyl.xlsx")
    for key in keys: 
        print(key)
        df = pd.read_excel("/home/annebusch/anne02/euf-data/damm-seq/GSE148202_Misincorporation_in-vivo_dsRNA_AllMethyl.xlsx", sheet_name=key)
        empty_columns = df.columns[df.isna().all()].tolist()
        empty_col_indices = [df.columns.get_loc(col) for col in empty_columns]
        empty_rows = df.index[df.isna().all(axis=1)].tolist()
        # print(empty_rows)
        # print(empty_columns)
        df_list = []
        row_splits = [-1] + empty_rows + [df.shape[0]]
        col_splits = [-1] + empty_col_indices + [df.shape[1]]
        # one sheet of this file contains multiple tables and this seperates them into subtables
        for i in range(len(row_splits) - 1):
            for j in range(len(col_splits) - 1):
                start_row, end_row = row_splits[i] + 1, row_splits[i + 1]
                start_col, end_col = col_splits[j] + 1, col_splits[j + 1]
                sub_df = df.iloc[start_row:end_row, start_col:end_col]
                if j != 0:
                    #print("here")
                    meta_info_start_row, metainfo_end_row = row_splits[i] + 1, row_splits[i] + 4
                    meta_info_start_col, metainfo_end_col = col_splits[0] + 1, col_splits[0] + 4
                    meta_info_df = df.iloc[meta_info_start_row:metainfo_end_row, meta_info_start_col:metainfo_end_col]
                    #print(meta_info_df)
                    if not sub_df.empty and sub_df.notna().any().any():
                        sub_df = pd.concat([meta_info_df, sub_df], ignore_index=True, axis=1)
                if not sub_df.empty and sub_df.notna().any().any():
                    sub_df = sub_df.dropna(how='all')
                    df_list.append(sub_df)
                    
        print(df_list)
        for dfl in df_list:
            print(dfl)
            chrom = "MT"
            pos = dfl.iloc[0, 1]
            strand = dfl.iloc[1, 1]
            modification = dfl.iloc[0, 2]
            split_at = "N"
            if "A" in modification:
                split_at = "A"
            if "G" in modification:
                split_at = "G"
            if "C" in modification:
                split_at = "C"
            split_mod, _ = modification.split(split_at)
            modi = split_mod + split_at
            if "22" in modi:
                modi = re.sub(r'22', '2,2', modi)
            # print(pos)
            # print(strand)
            # print(modi)
            if dfl.shape[1] == 12:
                df_input_subset = dfl.iloc[1:12, 3:12]
                column_names = ["Input", "A", "C", "G", "T", "GT", "GC", "GA", "Mu"]
                df_input_subset.columns = column_names
            else:
                df_input_subset = dfl.iloc[1:12, 3:9]
                column_names = ["Input", "A", "C", "G", "T", "Mu"]
                df_input_subset.columns = column_names
            print(df_input_subset)
            directory = "/home/annebusch/anne02/euf-data/damm-seq/"
            config_yaml = "/home/annebusch/anne02/euf-data/damm-seq/hela_config.yaml"
            for index, row in df_input_subset.iterrows():
                file = row.Input.replace(" ", "")
                file = file.replace("/", "")
                is_nan = pd.isnull(row.A)
                if isinstance(row.A, (int, float)) and (not is_nan):
                    coverage = int(row.A) + int(row.C) + int(row.G) + int(row["T"]) 
                    frequency = int(float(row.Mu) * 100)
                    score = int(float(row.Mu) * 1000)
                    # print(score)
                    # print(frequency)
                    print(file)
                    if os.path.isfile(directory+file+"Misincorporation_in-vivo_dsRNA_AllMethyl.bedrmod"):
                        with open(directory+file+"Misincorporation_in-vivo_dsRNA_AllMethyl.bedrmod", "a") as data:
                            data.write(f"{chrom}\t{pos}\t{pos+1}\t{modi}\t{score}\t{strand}\t{pos}\t{pos+1}\t{0,0,0}\t{coverage}\t{frequency}\n")   
                    else:
                        with open(directory+file+"Misincorporation_in-vivo_dsRNA_AllMethyl.bedrmod", "w") as data:
                            config = yaml.safe_load(open(config_yaml, "r"))
                            write_header(config, data)
                            data.write("#chrom\tchromStart\tchromEnd\tname\tscore\tstrand\tthickStart\tthickEnd\titemRgb\tcoverage\tfrequency\n")
                            data.write(f"{chrom}\t{pos}\t{pos+1}\t{modi}\t{score}\t{strand}\t{pos}\t{pos+1}\t{0,0,0}\t{coverage}\t{frequency}\n")

convert_damm_vivo_ds()
# Out:
# Ile
# [  mt-Ile region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0          chrM       4285     m22G26                 NaN          A
# 1           NaN          +        NaN  HeLa o/e Control-1          0
# 2           NaN        NaN        NaN  HeLa o/e Control-2          1
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1          0
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2          1
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1         21         45         15   0.444444
# 2         15         40         10   0.393939
# 3         20         59          9   0.329545
# 4         14         60         13   0.318182  ,       0     1       2                  3  4   5   6   7         8
# 0  chrM  4285  m22G26                NaN  A   C   G   T        Mu
# 1   NaN     +     NaN         HepG2 WT-1  1  16  31  12  0.483333
# 2   NaN   NaN     NaN         HepG2 WT-2  2  12  22  12  0.541667
# 3   NaN   NaN     NaN  HepG2 ALKBH7 KO-1  1  18  13  24  0.767857
# 4   NaN   NaN     NaN  HepG2 ALKBH7 KO-2  2  17  13  16  0.729167
# 5   NaN   NaN     NaN  HepG2 siControl-1  0  10  33   8  0.352941
# 6   NaN   NaN     NaN  HepG2 siControl-2  1  22  54  17  0.425532
# 7   NaN   NaN     NaN   HepG2 siALKBH7-1  0  17  16   6  0.589744
# 8   NaN   NaN     NaN   HepG2 siALKBH7-2  0  23  24  15  0.612903,       0     1       2                 3  4   5   6  7         8
# 0  chrM  4285  m22G26               NaN  A   C   G  T        Mu
# 1   NaN     +     NaN  HeLa shControl-1  1  14   7  6      0.75
# 2   NaN   NaN     NaN  HeLa shControl-2  1   8   8  5  0.636364
# 3   NaN   NaN     NaN    HeLa shTRMT1-1  1   4  21  4       0.3
# 4   NaN   NaN     NaN    HeLa shTRMT1-2  0   2  28  3  0.151515,    mt-Ile region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
#
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
#       0     1       2                 3  4   5   6  7         8
# 0  chrM  4285  m22G26               NaN  A   C   G  T        Mu
# 1   NaN     +     NaN  HeLa shControl-1  1  14   7  6      0.75
# 2   NaN   NaN     NaN  HeLa shControl-2  1   8   8  5  0.636364
# 3   NaN   NaN     NaN    HeLa shTRMT1-1  1   4  21  4       0.3
# 4   NaN   NaN     NaN    HeLa shTRMT1-2  0   2  28  3  0.151515
#               Input  A   C   G  T        Mu
# 1  HeLa shControl-1  1  14   7  6      0.75
# 2  HeLa shControl-2  1   8   8  5  0.636364
# 3    HeLa shTRMT1-1  1   4  21  4       0.3
# 4    HeLa shTRMT1-2  0   2  28  3  0.151515
# HeLashControl-1
# HeLashControl-2
# HeLashTRMT1-1
# HeLashTRMT1-2
#    mt-Ile region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 11          chrM       4272       m1G9                 NaN          A
# 12           NaN          +        NaN  HeLa o/e Control-1          0
# 13           NaN        NaN        NaN  HeLa o/e Control-2          1
# 14           NaN        NaN        NaN   HeLa o/e ALKBH7-1          1
# 15           NaN        NaN        NaN   HeLa o/e ALKBH7-2          1
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 11          C          G          T         Mu
# 12         10         61          1   0.152778
# 13          3         48          0   0.076923
# 14         15         77          3   0.197917
# 15         12         72          1   0.162791
#                  Input  A   C   G  T        Mu
# 12  HeLa o/e Control-1  0  10  61  1  0.152778
# 13  HeLa o/e Control-2  1   3  48  0  0.076923
# 14   HeLa o/e ALKBH7-1  1  15  77  3  0.197917
# 15   HeLa o/e ALKBH7-2  1  12  72  1  0.162791
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#        0     1     2                  3  4   5   6  7         8
# 11  chrM  4272  m1G9                NaN  A   C   G  T        Mu
# 12   NaN     +   NaN         HepG2 WT-1  3   5  43  4  0.218182
# 13   NaN   NaN   NaN         HepG2 WT-2  2   6  25  4  0.324324
# 14   NaN   NaN   NaN  HepG2 ALKBH7 KO-1  1   5  29  4   0.25641
# 15   NaN   NaN   NaN  HepG2 ALKBH7 KO-2  2   5  28  4  0.282051
# 16   NaN   NaN   NaN  HepG2 siControl-1  0   3  33  1  0.108108
# 17   NaN   NaN   NaN  HepG2 siControl-2  4  18  42  5  0.391304
# 18   NaN   NaN   NaN   HepG2 siALKBH7-1  0   5  18  1      0.25
# 19   NaN   NaN   NaN   HepG2 siALKBH7-2  0   8  42  4  0.222222
#                 Input  A   C   G  T        Mu
# 12         HepG2 WT-1  3   5  43  4  0.218182
# 13         HepG2 WT-2  2   6  25  4  0.324324
# 14  HepG2 ALKBH7 KO-1  1   5  29  4   0.25641
# 15  HepG2 ALKBH7 KO-2  2   5  28  4  0.282051
# 16  HepG2 siControl-1  0   3  33  1  0.108108
# 17  HepG2 siControl-2  4  18  42  5  0.391304
# 18   HepG2 siALKBH7-1  0   5  18  1      0.25
# 19   HepG2 siALKBH7-2  0   8  42  4  0.222222
# HepG2WT-1
# HepG2WT-2
# HepG2ALKBH7KO-1
# HepG2ALKBH7KO-2
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# Arg
# [  mt-Arg region Unnamed: 1 Unnamed: 2          Unnamed: 3   Unnamed: 4  \
# 0          chrM      10414       m1A9                 NaN            A
# 1           NaN          +        NaN  HeLa o/e Control-1          NaN
# 2           NaN        NaN        NaN  HeLa o/e Control-2  (low reads)
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1  (low reads)
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2  (low reads)
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN  ,       0      1     2                  3            4    5    6    7         8
# 0  chrM  10414  m1A9                NaN            A    C    G    T        Mu
# 1   NaN      +   NaN         HepG2 WT-1  (low reads)  NaN  NaN  NaN       NaN
# 2   NaN    NaN   NaN         HepG2 WT-2  (low reads)  NaN  NaN  NaN       NaN
# 3   NaN    NaN   NaN  HepG2 ALKBH7 KO-1  (low reads)  NaN  NaN  NaN       NaN
# 4   NaN    NaN   NaN  HepG2 ALKBH7 KO-2  (low reads)  NaN  NaN  NaN       NaN
# 5   NaN    NaN   NaN  HepG2 siControl-1            3    1    2   19      0.88
# 6   NaN    NaN   NaN  HepG2 siControl-2           12    2    0   41  0.781818
# 7   NaN    NaN   NaN   HepG2 siALKBH7-1            6    1    4   30  0.853659
# 8   NaN    NaN   NaN   HepG2 siALKBH7-2           13    4    1   42  0.783333]
#   mt-Arg region Unnamed: 1 Unnamed: 2          Unnamed: 3   Unnamed: 4  \
# 0          chrM      10414       m1A9                 NaN            A
# 1           NaN          +        NaN  HeLa o/e Control-1          NaN
# 2           NaN        NaN        NaN  HeLa o/e Control-2  (low reads)
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1  (low reads)
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2  (low reads)
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN
#                 Input            A    C    G    T   Mu
# 1  HeLa o/e Control-1          NaN  NaN  NaN  NaN  NaN
# 2  HeLa o/e Control-2  (low reads)  NaN  NaN  NaN  NaN
# 3   HeLa o/e ALKBH7-1  (low reads)  NaN  NaN  NaN  NaN
# 4   HeLa o/e ALKBH7-2  (low reads)  NaN  NaN  NaN  NaN
#       0      1     2                  3            4    5    6    7         8
# 0  chrM  10414  m1A9                NaN            A    C    G    T        Mu
# 1   NaN      +   NaN         HepG2 WT-1  (low reads)  NaN  NaN  NaN       NaN
# 2   NaN    NaN   NaN         HepG2 WT-2  (low reads)  NaN  NaN  NaN       NaN
# 3   NaN    NaN   NaN  HepG2 ALKBH7 KO-1  (low reads)  NaN  NaN  NaN       NaN
# 4   NaN    NaN   NaN  HepG2 ALKBH7 KO-2  (low reads)  NaN  NaN  NaN       NaN
# 5   NaN    NaN   NaN  HepG2 siControl-1            3    1    2   19      0.88
# 6   NaN    NaN   NaN  HepG2 siControl-2           12    2    0   41  0.781818
# 7   NaN    NaN   NaN   HepG2 siALKBH7-1            6    1    4   30  0.853659
# 8   NaN    NaN   NaN   HepG2 siALKBH7-2           13    4    1   42  0.783333
#                Input            A    C    G    T        Mu
# 1         HepG2 WT-1  (low reads)  NaN  NaN  NaN       NaN
# 2         HepG2 WT-2  (low reads)  NaN  NaN  NaN       NaN
Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0           chrM      12275       m1A9                 NaN          A
# 1            NaN          +        NaN  HeLa o/e Control-1         43
# 2            NaN        NaN        NaN  HeLa o/e Control-2         44
# 3            NaN        NaN        NaN   HeLa o/e ALKBH7-1         61
# 4            NaN        NaN        NaN   HeLa o/e ALKBH7-2         50
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1          7         24         64   0.688406
# 2         11         20         72    0.70068
# 3         16         26         94   0.690355
# 4          9         16         40   0.565217
#                 Input   A   C   G   T        Mu
# 1  HeLa o/e Control-1  43   7  24  64  0.688406
# 2  HeLa o/e Control-2  44  11  20  72   0.70068
# 3   HeLa o/e ALKBH7-1  61  16  26  94  0.690355
# 4   HeLa o/e ALKBH7-2  50   9  16  40  0.565217
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#       0      1     2                  3   4   5   6   7         8
# 0  chrM  12275  m1A9                NaN   A   C   G   T        Mu
# 1   NaN      +   NaN         HepG2 WT-1  29   4  13  36  0.646341
# 2   NaN    NaN   NaN         HepG2 WT-2  30   4  14  41  0.662921
# 3   NaN    NaN   NaN  HepG2 ALKBH7 KO-1  18   2   8  21  0.632653
# 4   NaN    NaN   NaN  HepG2 ALKBH7 KO-2  11   1   5  20  0.702703
# 5   NaN    NaN   NaN  HepG2 siControl-1  32   5   6  40  0.614458
# 6   NaN    NaN   NaN  HepG2 siControl-2  56   4  16  74  0.626667
# 7   NaN    NaN   NaN   HepG2 siALKBH7-1  36   2  11  32  0.555556
# 8   NaN    NaN   NaN   HepG2 siALKBH7-2  47  12  14  49  0.614754
#                Input   A   C   G   T        Mu
# 1         HepG2 WT-1  29   4  13  36  0.646341
# 2         HepG2 WT-2  30   4  14  41  0.662921
# 3  HepG2 ALKBH7 KO-1  18   2   8  21  0.632653
# 4  HepG2 ALKBH7 KO-2  11   1   5  20  0.702703
# 5  HepG2 siControl-1  32   5   6  40  0.614458
# 6  HepG2 siControl-2  56   4  16  74  0.626667
# 7   HepG2 siALKBH7-1  36   2  11  32  0.555556
# 8   HepG2 siALKBH7-2  47  12  14  49  0.614754
# HepG2WT-1
# HepG2WT-2
# HepG2ALKBH7KO-1
# HepG2ALKBH7KO-2
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
#    mt-Leu1 region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 10           chrM      12302      m1G37                 NaN          A
# 11            NaN          +        NaN  HeLa o/e Control-1          5
# 12            NaN        NaN        NaN  HeLa o/e Control-2          4
# 13            NaN        NaN        NaN   HeLa o/e ALKBH7-1          6
# 14            NaN        NaN        NaN   HeLa o/e ALKBH7-2          4
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          C          G          T         Mu
# 11         58        274         13   0.217143
# 12         59        314         16   0.201018
# 13        106        353         23   0.276639
# 14         74        297         21       0.25
#                  Input  A    C    G   T        Mu
# 11  HeLa o/e Control-1  5   58  274  13  0.217143
# 12  HeLa o/e Control-2  4   59  314  16  0.201018
# 13   HeLa o/e ALKBH7-1  6  106  353  23  0.276639
# 14   HeLa o/e ALKBH7-2  4   74  297  21      0.25
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#       0     1     2                  3   4  5  6   7         8
# 0  chrM  5521  m1A9                NaN   A  C  G   T        Mu
# 1   NaN     +   NaN         HepG2 WT-1  29  3  4  45  0.641975
# 2   NaN   NaN   NaN         HepG2 WT-2  33  4  5  31  0.547945
# 3   NaN   NaN   NaN  HepG2 ALKBH7 KO-1  13  0  6  45  0.796875
# 4   NaN   NaN   NaN  HepG2 ALKBH7 KO-2  17  6  6  36  0.738462
# 5   NaN   NaN   NaN  HepG2 siControl-1  36  0  1  20  0.368421
# 6   NaN   NaN   NaN  HepG2 siControl-2  49  7  2  41  0.505051
# 7   NaN   NaN   NaN   HepG2 siALKBH7-1  11  1  2  24  0.710526
# 8   NaN   NaN   NaN   HepG2 siALKBH7-2  36  5  1  44  0.581395
#                Input   A  C  G   T        Mu
# 1         HepG2 WT-1  29  3  4  45  0.641975
# 2         HepG2 WT-2  33  4  5  31  0.547945
# 3  HepG2 ALKBH7 KO-1  13  0  6  45  0.796875
# 4  HepG2 ALKBH7 KO-2  17  6  6  36  0.738462
# 5  HepG2 siControl-1  36  0  1  20  0.368421
# 6  HepG2 siControl-2  49  7  2  41  0.505051
# 7   HepG2 siALKBH7-1  11  1  2  24  0.710526
# 8   HepG2 siALKBH7-2  36  5  1  44  0.581395
# HepG2WT-1
# HepG2WT-2
# HepG2ALKBH7KO-1
# HepG2ALKBH7KO-2
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# His
# [  mt-His region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0          chrM      12147       m1A9                 NaN          A
# 1           NaN          +        NaN  HeLa o/e Control-1          7
# 2           NaN        NaN        NaN  HeLa o/e Control-2         10
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1         15
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2          9
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1          7          4         36    0.87037
# 2          2          1         24    0.72973
# 3          7          1         43   0.772727
# 4          3          6         25   0.790698  ,       0      1     2                  3   4  5  6   7         8
# 0  chrM  12147  m1A9                NaN   A  C  G   T        Mu
# 1   NaN      +   NaN         HepG2 WT-1   4  1  1  22  0.857143
# 2   NaN    NaN   NaN         HepG2 WT-2  12  0  1  20  0.636364
# 3   NaN    NaN   NaN  HepG2 ALKBH7 KO-1  11  2  1   9  0.521739
# 4   NaN    NaN   NaN  HepG2 ALKBH7 KO-2   5  1  1   8  0.666667
# 5   NaN    NaN   NaN  HepG2 siControl-1  12  1  4  36  0.773585
# 6   NaN    NaN   NaN  HepG2 siControl-2  13  3  1  56  0.821918
# 7   NaN    NaN   NaN   HepG2 siALKBH7-1   8  3  3  48  0.870968
# 8   NaN    NaN   NaN   HepG2 siALKBH7-2  13  9  2  44  0.808824]
#   mt-His region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0          chrM      12147       m1A9                 NaN          A
# 1           NaN          +        NaN  HeLa o/e Control-1          7
# 2           NaN        NaN        NaN  HeLa o/e Control-2         10
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1         15
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2          9
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1          7          4         36    0.87037
# 2          2          1         24    0.72973
# 3          7          1         43   0.772727
# 4          3          6         25   0.790698
#                 Input   A  C  G   T        Mu
# 1  HeLa o/e Control-1   7  7  4  36   0.87037
# 2  HeLa o/e Control-2  10  2  1  24   0.72973
# 3   HeLa o/e ALKBH7-1  15  7  1  43  0.772727
# 4   HeLa o/e ALKBH7-2   9  3  6  25  0.790698
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#       0      1     2                  3   4  5  6   7         8
# 0  chrM  12147  m1A9                NaN   A  C  G   T        Mu
# 1   NaN      +   NaN         HepG2 WT-1   4  1  1  22  0.857143
# 2   NaN    NaN   NaN         HepG2 WT-2  12  0  1  20  0.636364
# 3   NaN    NaN   NaN  HepG2 ALKBH7 KO-1  11  2  1   9  0.521739
# 4   NaN    NaN   NaN  HepG2 ALKBH7 KO-2   5  1  1   8  0.666667
# 5   NaN    NaN   NaN  HepG2 siControl-1  12  1  4  36  0.773585
# 6   NaN    NaN   NaN  HepG2 siControl-2  13  3  1  56  0.821918
# 7   NaN    NaN   NaN   HepG2 siALKBH7-1   8  3  3  48  0.870968
# 8   NaN    NaN   NaN   HepG2 siALKBH7-2  13  9  2  44  0.808824
#                Input   A  C  G   T        Mu
# 1         HepG2 WT-1   4  1  1  22  0.857143
# 2         HepG2 WT-2  12  0  1  20  0.636364
# 3  HepG2 ALKBH7 KO-1  11  2  1   9  0.521739
# 4  HepG2 ALKBH7 KO-2   5  1  1   8  0.666667
# 5  HepG2 siControl-1  12  1  4  36  0.773585
# 6  HepG2 siControl-2  13  3  1  56  0.821918
# 7   HepG2 siALKBH7-1   8  3  3  48  0.870968
# 8   HepG2 siALKBH7-2  13  9  2  44  0.808824
# HepG2WT-1
# HepG2WT-2
# HepG2ALKBH7KO-1
# HepG2ALKBH7KO-2
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# Phe
# [  mt-Phe region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0          chrM        587       m1A9                 NaN          A
# 1           NaN          +        NaN  HeLa o/e Control-1        552
# 2           NaN        NaN        NaN  HeLa o/e Control-2        478
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1       1000
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2        757
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1         62        102        566   0.569423
# 2         42         63        403   0.515213
# 3         94        173        887   0.535747
# 4         62        106        576    0.49567  ,       0    1     2                  3    4   5    6    7         8
# 0  chrM  587  m1A9                NaN    A   C    G    T        Mu
# 1   NaN    +   NaN         HepG2 WT-1  398  55   79  457  0.597573
# 2   NaN  NaN   NaN         HepG2 WT-2  336  40   82  385  0.601423
# 3   NaN  NaN   NaN  HepG2 ALKBH7 KO-1  185  18   40  196  0.578588
# 4   NaN  NaN   NaN  HepG2 ALKBH7 KO-2  196  33   40  208  0.589099
# 5   NaN  NaN   NaN  HepG2 siControl-1  508  40   48  462  0.519849
# 6   NaN  NaN   NaN  HepG2 siControl-2  835  80  120  900  0.568475
# 7   NaN  NaN   NaN   HepG2 siALKBH7-1  179  30   46  304  0.679785
# 8   NaN  NaN   NaN   HepG2 siALKBH7-2  378  80  110  669  0.694422]
#   mt-Phe region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0          chrM        587       m1A9                 NaN          A
# 1           NaN          +        NaN  HeLa o/e Control-1        552
# 2           NaN        NaN        NaN  HeLa o/e Control-2        478
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1       1000
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2        757
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1         62        102        566   0.569423
# 2         42         63        403   0.515213
# 3         94        173        887   0.535747
# 4         62        106        576    0.49567
#                 Input     A   C    G    T        Mu
# 1  HeLa o/e Control-1   552  62  102  566  0.569423
# 2  HeLa o/e Control-2   478  42   63  403  0.515213
# 3   HeLa o/e ALKBH7-1  1000  94  173  887  0.535747
# 4   HeLa o/e ALKBH7-2   757  62  106  576   0.49567
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#       0    1     2                  3    4   5    6    7         8
# 0  chrM  587  m1A9                NaN    A   C    G    T        Mu
# 1   NaN    +   NaN         HepG2 WT-1  398  55   79  457  0.597573
# 2   NaN  NaN   NaN         HepG2 WT-2  336  40   82  385  0.601423
# 3   NaN  NaN   NaN  HepG2 ALKBH7 KO-1  185  18   40  196  0.578588
# 4   NaN  NaN   NaN  HepG2 ALKBH7 KO-2  196  33   40  208  0.589099
# 5   NaN  NaN   NaN  HepG2 siControl-1  508  40   48  462  0.519849
# 6   NaN  NaN   NaN  HepG2 siControl-2  835  80  120  900  0.568475
# 7   NaN  NaN   NaN   HepG2 siALKBH7-1  179  30   46  304  0.679785
# 8   NaN  NaN   NaN   HepG2 siALKBH7-2  378  80  110  669  0.694422
#                Input    A   C    G    T        Mu
# 1         HepG2 WT-1  398  55   79  457  0.597573
# 2         HepG2 WT-2  336  40   82  385  0.601423
# 3  HepG2 ALKBH7 KO-1  185  18   40  196  0.578588
# 4  HepG2 ALKBH7 KO-2  196  33   40  208  0.589099
# 5  HepG2 siControl-1  508  40   48  462  0.519849
# 6  HepG2 siControl-2  835  80  120  900  0.568475
# 7   HepG2 siALKBH7-1  179  30   46  304  0.679785
# 8   HepG2 siALKBH7-2  378  80  110  669  0.694422
# HepG2WT-1
# HepG2WT-2
# HepG2ALKBH7KO-1
# HepG2ALKBH7KO-2
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# Gly
# [  mt-Gly region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0          chrM      10000       m1A9                 NaN          A
# 1           NaN          +        NaN  HeLa o/e Control-1          5
# 2           NaN        NaN        NaN  HeLa o/e Control-2          2
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1          8
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2          7
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1          2          1         12       0.75
# 2          0          5         11   0.888889
# 3          2          2          6   0.555556
# 4          2          1         11   0.666667  ,       0      1     2                  3   4  5  6   7         8
# 0  chrM  10000  m1A9                NaN   A  C  G   T        Mu
# 1   NaN      +   NaN         HepG2 WT-1   5  1  1   4  0.545455
# 2   NaN    NaN   NaN         HepG2 WT-2  10  1  3   8  0.545455
# 3   NaN    NaN   NaN  HepG2 ALKBH7 KO-1   9  2  1   6       0.5
# 4   NaN    NaN   NaN  HepG2 ALKBH7 KO-2   5  2  1   3  0.545455
# 5   NaN    NaN   NaN  HepG2 siControl-1   9  3  2  13  0.666667
# 6   NaN    NaN   NaN  HepG2 siControl-2  14  6  6  41  0.791045
# 7   NaN    NaN   NaN   HepG2 siALKBH7-1   9  3  5  30  0.808511
# 8   NaN    NaN   NaN   HepG2 siALKBH7-2  13  4  4  60  0.839506]
#   mt-Gly region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0          chrM      10000       m1A9                 NaN          A
# 1           NaN          +        NaN  HeLa o/e Control-1          5
# 2           NaN        NaN        NaN  HeLa o/e Control-2          2
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1          8
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2          7
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1          2          1         12       0.75
# 2          0          5         11   0.888889
# 3          2          2          6   0.555556
# 4          2          1         11   0.666667
#                 Input  A  C  G   T        Mu
# 1  HeLa o/e Control-1  5  2  1  12      0.75
# 2  HeLa o/e Control-2  2  0  5  11  0.888889
# 3   HeLa o/e ALKBH7-1  8  2  2   6  0.555556
# 4   HeLa o/e ALKBH7-2  7  2  1  11  0.666667
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#       0      1     2                  3   4  5  6   7         8
# 0  chrM  10000  m1A9                NaN   A  C  G   T        Mu
# 1   NaN      +   NaN         HepG2 WT-1   5  1  1   4  0.545455
# 2   NaN    NaN   NaN         HepG2 WT-2  10  1  3   8  0.545455
# 3   NaN    NaN   NaN  HepG2 ALKBH7 KO-1   9  2  1   6       0.5
# 4   NaN    NaN   NaN  HepG2 ALKBH7 KO-2   5  2  1   3  0.545455
# 5   NaN    NaN   NaN  HepG2 siControl-1   9  3  2  13  0.666667
# 6   NaN    NaN   NaN  HepG2 siControl-2  14  6  6  41  0.791045
# 7   NaN    NaN   NaN   HepG2 siALKBH7-1   9  3  5  30  0.808511
# 8   NaN    NaN   NaN   HepG2 siALKBH7-2  13  4  4  60  0.839506
#                Input   A  C  G   T        Mu
# 1         HepG2 WT-1   5  1  1   4  0.545455
# 2         HepG2 WT-2  10  1  3   8  0.545455
# 3  HepG2 ALKBH7 KO-1   9  2  1   6       0.5
# 4  HepG2 ALKBH7 KO-2   5  2  1   3  0.545455
# 5  HepG2 siControl-1   9  3  2  13  0.666667
# 6  HepG2 siControl-2  14  6  6  41  0.791045
# 7   HepG2 siALKBH7-1   9  3  5  30  0.808511
# 8   HepG2 siALKBH7-2  13  4  4  60  0.839506
# HepG2WT-1
# HepG2WT-2
# HepG2ALKBH7KO-1
# HepG2ALKBH7KO-2
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# Val
# [  mt-Val region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0          chrM       1612       m1A9                 NaN          A
# 1           NaN          +        NaN  HeLa o/e Control-1        373
# 2           NaN        NaN        NaN  HeLa o/e Control-2        288
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1        583
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2        486
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1        103        114        723   0.715918
# 2         66        114        511   0.705822
# 3         97        147        684   0.614163
# 4         57         97        443   0.551247  ,       0     1     2                  3    4   5    6    7         8
# 0  chrM  1612  m1A9                NaN    A   C    G    T        Mu
# 1   NaN     +   NaN         HepG2 WT-1  563  84   94  590   0.57701
# 2   NaN   NaN   NaN         HepG2 WT-2  559  81   82  508  0.545528
# 3   NaN   NaN   NaN  HepG2 ALKBH7 KO-1  205  91   79  475  0.758824
# 4   NaN   NaN   NaN  HepG2 ALKBH7 KO-2  179  88  101  495  0.792584
# 5   NaN   NaN   NaN  HepG2 siControl-1  259  36   20  179  0.475709
# 6   NaN   NaN   NaN  HepG2 siControl-2  346  37   58  324  0.547712
# 7   NaN   NaN   NaN   HepG2 siALKBH7-1   90  22   21  149  0.680851
# 8   NaN   NaN   NaN   HepG2 siALKBH7-2  138  36   42  266  0.713693]
#   mt-Val region Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0          chrM       1612       m1A9                 NaN          A
# 1           NaN          +        NaN  HeLa o/e Control-1        373
# 2           NaN        NaN        NaN  HeLa o/e Control-2        288
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1        583
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2        486
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1        103        114        723   0.715918
# 2         66        114        511   0.705822
# 3         97        147        684   0.614163
# 4         57         97        443   0.551247
#                 Input    A    C    G    T        Mu
# 1  HeLa o/e Control-1  373  103  114  723  0.715918
# 2  HeLa o/e Control-2  288   66  114  511  0.705822
# 3   HeLa o/e ALKBH7-1  583   97  147  684  0.614163
# 4   HeLa o/e ALKBH7-2  486   57   97  443  0.551247
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0          chrM      13711        m1A                 NaN          A
# 1           NaN          +        NaN  HeLa o/e Control-1        647
# 2           NaN        NaN        NaN  HeLa o/e Control-2        643
# 3           NaN        NaN        NaN   HeLa o/e ALKBH7-1        805
# 4           NaN        NaN        NaN   HeLa o/e ALKBH7-2        604
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          C          G          T         Mu
# 1          5          9         61   0.103878
# 2          5          6         56   0.094366
# 3          5         12         51   0.077892
# 4          3         10         31   0.067901
#                 Input    A  C   G   T        Mu
# 1  HeLa o/e Control-1  647  5   9  61  0.103878
# 2  HeLa o/e Control-2  643  5   6  56  0.094366
# 3   HeLa o/e ALKBH7-1  805  5  12  51  0.077892
# 4   HeLa o/e ALKBH7-2  604  3  10  31  0.067901
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#       0      1    2                  3     4   5   6   7         8
# 0  chrM  13711  m1A                NaN     A   C   G   T        Mu
# 1   NaN      +  NaN         HepG2 WT-1  2096   9  25  68  0.046406
# 2   NaN    NaN  NaN         HepG2 WT-2  2085  14  16  64  0.043139
# 3   NaN    NaN  NaN  HepG2 ALKBH7 KO-1   822   5   4  24  0.038596
# 4   NaN    NaN  NaN  HepG2 ALKBH7 KO-2   889   4   5  19  0.030534
# 5   NaN    NaN  NaN  HepG2 siControl-1   841   5   2  24   0.03555
# 6   NaN    NaN  NaN  HepG2 siControl-2   932   1   7  22  0.031185
# 7   NaN    NaN  NaN   HepG2 siALKBH7-1   276   0   0  10  0.034965
# 8   NaN    NaN  NaN   HepG2 siALKBH7-2   471   4   6  11  0.042683
#                Input     A   C   G   T        Mu
# 1         HepG2 WT-1  2096   9  25  68  0.046406
# 2         HepG2 WT-2  2085  14  16  64  0.043139
# 3  HepG2 ALKBH7 KO-1   822   5   4  24  0.038596
# 4  HepG2 ALKBH7 KO-2   889   4   5  19  0.030534
# 5  HepG2 siControl-1   841   5   2  24   0.03555
# 6  HepG2 siControl-2   932   1   7  22  0.031185
# 7   HepG2 siALKBH7-1   276   0   0  10  0.034965
# 8   HepG2 siALKBH7-2   471   4   6  11  0.042683
# HepG2WT-1
# HepG2WT-2
# HepG2ALKBH7KO-1
# HepG2ALKBH7KO-2
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2

# %%
def convert_damm_vivo_mt():
    def score_func(mu_col):
        return int(float(mu_col) * 1000)
    def frequency_func(mu_col):
        return int(float(mu_col) * 100)

    keys = parse_excel("/home/annebusch/anne02/euf-data/damm-seq/GSE148202_Misincorporation_in-vivo_mt-tRNA_AllMethyl.xlsx")
    for key in keys: 
        print(key)
        df = pd.read_excel("/home/annebusch/anne02/euf-data/damm-seq/GSE148202_Misincorporation_in-vivo_mt-tRNA_AllMethyl.xlsx", sheet_name=key)
        empty_columns = df.columns[df.isna().all()].tolist()
        empty_col_indices = [df.columns.get_loc(col) for col in empty_columns]
        empty_rows = df.index[df.isna().all(axis=1)].tolist()
        # print(empty_rows)
        # print(empty_columns)
        df_list = []
        row_splits = [-1] + empty_rows + [df.shape[0]]
        col_splits = [-1] + empty_col_indices + [df.shape[1]]
        # one sheet of this file contains multiple tables and this seperates them into subtables
        for i in range(len(row_splits) - 1):
            for j in range(len(col_splits) - 1):
                start_row, end_row = row_splits[i] + 1, row_splits[i + 1]
                start_col, end_col = col_splits[j] + 1, col_splits[j + 1]
                sub_df = df.iloc[start_row:end_row, start_col:end_col]
                if j != 0:
                    #print("here")
                    meta_info_start_row, metainfo_end_row = row_splits[i] + 1, row_splits[i] + 4
                    meta_info_start_col, metainfo_end_col = col_splits[0] + 1, col_splits[0] + 4
                    meta_info_df = df.iloc[meta_info_start_row:metainfo_end_row, meta_info_start_col:metainfo_end_col]
                    #print(meta_info_df)
                    if not sub_df.empty and sub_df.notna().any().any():
                        sub_df = pd.concat([meta_info_df, sub_df], ignore_index=True, axis=1)
                if not sub_df.empty and sub_df.notna().any().any():
                    sub_df = sub_df.dropna(how='all')
                    df_list.append(sub_df)
                    
        print(df_list)
        for dfl in df_list:
            print(dfl)
            chrom = "MT"
            pos = dfl.iloc[0, 1]
            strand = dfl.iloc[1, 1]
            modification = dfl.iloc[0, 2]
            split_at = "N"
            if "A" in modification:
                split_at = "A"
            if "G" in modification:
                split_at = "G"
            if "C" in modification:
                split_at = "C"
            split_mod, _ = modification.split(split_at)
            modi = split_mod + split_at
            if "22" in modi:
                modi = re.sub(r'22', '2,2', modi)
            # print(pos)
            # print(strand)
            # print(modi)
            if dfl.shape[1] == 12:
                df_input_subset = dfl.iloc[1:12, 3:12]
                column_names = ["Input", "A", "C", "G", "T", "GT", "GC", "GA", "Mu"]
                df_input_subset.columns = column_names
            else:
                df_input_subset = dfl.iloc[1:12, 3:9]
                column_names = ["Input", "A", "C", "G", "T", "Mu"]
                df_input_subset.columns = column_names
            print(df_input_subset)
            directory = "/home/annebusch/anne02/euf-data/damm-seq/"
            config_yaml = "/home/annebusch/anne02/euf-data/damm-seq/hela_config.yaml"
            for index, row in df_input_subset.iterrows():
                file = row.Input.replace(" ", "")
                file = file.replace("/", "")
                is_nan = pd.isnull(row.A)
                if isinstance(row.A, (int, float)) and (not is_nan):
                    coverage = int(row.A) + int(row.C) + int(row.G) + int(row["T"]) 
                    frequency = int(float(row.Mu) * 100)
                    score = int(float(row.Mu) * 1000)
                    # print(score)
                    # print(frequency)
                    print(file)
                    if os.path.isfile(directory+file+"Misincorporation_in-vivo_mt-tRNA_AllMethyl.bedrmod"):
                        with open(directory+file+"Misincorporation_in-vivo_mt-tRNA_AllMethyl.bedrmod", "a") as data:
                            data.write(f"{chrom}\t{pos}\t{pos+1}\t{modi}\t{score}\t{strand}\t{pos}\t{pos+1}\t{0,0,0}\t{coverage}\t{frequency}\n")   
                    else:
                        with open(directory+file+"Misincorporation_in-vivo_mt-tRNA_AllMethyl.bedrmod", "w") as data:
                            config = yaml.safe_load(open(config_yaml, "r"))
                            write_header(config, data)
                            data.write("#chrom\tchromStart\tchromEnd\tname\tscore\tstrand\tthickStart\tthickEnd\titemRgb\tcoverage\tfrequency\n")
                            data.write(f"{chrom}\t{pos}\t{pos+1}\t{modi}\t{score}\t{strand}\t{pos}\t{pos+1}\t{0,0,0}\t{coverage}\t{frequency}\n")

convert_damm_vivo_mt()
# Out:
# Ile
# [  mt-Ile Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       4285     m22G26                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1         91       1079
# 2    NaN        NaN        NaN   HepG2 siControl-2        107       1367
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        149       1637
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        114       1434
# 5    NaN        NaN        NaN  HeLa o/e Control-1         67       1318
# 6    NaN        NaN        NaN  HeLa o/e Control-2         71       1367
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1         46       1218
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2         59       1212
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        332       1003   0.867465
# 2        328       1115   0.887556
# 3        460       1472   0.876278
# 4        348       1258   0.889664
# 5        151        977   0.939912
# 6        178       1045   0.933108
# 7        196        922   0.917716
# 8        189        941   0.921283  ,       0     1       2                 3   4    5    6    7         8
# 0  chrM  4285  m22G26               NaN   A    C    G    T        Mu
# 1   NaN     +     NaN  HeLa shControl-1  10  163   30  121  0.907407
# 2   NaN   NaN     NaN  HeLa shControl-2  10  197   38  136  0.900262
# 3   NaN   NaN     NaN    HeLa shTRMT1-1  13  150  318  106  0.458262
# 4   NaN   NaN     NaN    HeLa shTRMT1-2  14  141  350  136  0.453978,    mt-Ile Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 11   chrM       4272       m1G9                 NaN          A          C
# 12    NaN          +        NaN   HepG2 siControl-1         30        305
# 13    NaN        NaN        NaN   HepG2 siControl-2         38        359
# 14    NaN        NaN        NaN    HepG2 siALKBH7-1         59        483
# 15    NaN        NaN        NaN    HepG2 siALKBH7-2         32        381
# 16    NaN        NaN        NaN  HeLa o/e Control-1         60        582
# 17    NaN        NaN        NaN  HeLa o/e Control-2         58        559
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-1         52        510
# 19    NaN        NaN        NaN   HeLa o/e ALKBH7-2         46        532
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 11          G          T         Mu
# 12       1212         41   0.236776
# 13       1137         82   0.296411
# 14       1639         89   0.277974
# 15       1422         73   0.254717
# 16       2516        112   0.230581
# 17       2614        110     0.2176
# 18       2344         85   0.216316
# 19       2432         94   0.216495  ]
#   mt-Ile Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       4285     m22G26                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1         91       1079
# 2    NaN        NaN        NaN   HepG2 siControl-2        107       1367
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        149       1637
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        114       1434
# 5    NaN        NaN        NaN  HeLa o/e Control-1         67       1318
# 6    NaN        NaN        NaN  HeLa o/e Control-2         71       1367
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1         46       1218
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2         59       1212
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        332       1003   0.867465
# 2        328       1115   0.887556
# 3        460       1472   0.876278
# 4        348       1258   0.889664
# 5        151        977   0.939912
# 6        178       1045   0.933108
# 7        196        922   0.917716
# 8        189        941   0.921283
#                 Input    A     C    G     T        Mu
# 1   HepG2 siControl-1   91  1079  332  1003  0.867465
# 2   HepG2 siControl-2  107  1367  328  1115  0.887556
# 3    HepG2 siALKBH7-1  149  1637  460  1472  0.876278
# 4    HepG2 siALKBH7-2  114  1434  348  1258  0.889664
# 5  HeLa o/e Control-1   67  1318  151   977  0.939912
# 6  HeLa o/e Control-2   71  1367  178  1045  0.933108
# 7   HeLa o/e ALKBH7-1   46  1218  196   922  0.917716
# 8   HeLa o/e ALKBH7-2   59  1212  189   941  0.921283
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#       0     1       2                 3   4    5    6    7         8
# 0  chrM  4285  m22G26               NaN   A    C    G    T        Mu
# 1   NaN     +     NaN  HeLa shControl-1  10  163   30  121  0.907407
# 2   NaN   NaN     NaN  HeLa shControl-2  10  197   38  136  0.900262
# 3   NaN   NaN     NaN    HeLa shTRMT1-1  13  150  318  106  0.458262
# 4   NaN   NaN     NaN    HeLa shTRMT1-2  14  141  350  136  0.453978
#               Input   A    C    G    T        Mu
# 1  HeLa shControl-1  10  163   30  121  0.907407
# 2  HeLa shControl-2  10  197   38  136  0.900262
# 3    HeLa shTRMT1-1  13  150  318  106  0.458262
# 4    HeLa shTRMT1-2  14  141  350  136  0.453978
# HeLashControl-1
# HeLashControl-2
# HeLashTRMT1-1
# HeLashTRMT1-2
#    mt-Ile Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 11   chrM       4272       m1G9                 NaN          A          C
# 12    NaN          +        NaN   HepG2 siControl-1         30        305
# 13    NaN        NaN        NaN   HepG2 siControl-2         38        359
# 14    NaN        NaN        NaN    HepG2 siALKBH7-1         59        483
# 15    NaN        NaN        NaN    HepG2 siALKBH7-2         32        381
# 16    NaN        NaN        NaN  HeLa o/e Control-1         60        582
# 17    NaN        NaN        NaN  HeLa o/e Control-2         58        559
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-1         52        510
# 19    NaN        NaN        NaN   HeLa o/e ALKBH7-2         46        532
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 11          G          T         Mu
# 12       1212         41   0.236776
# 13       1137         82   0.296411
# 14       1639         89   0.277974
# 15       1422         73   0.254717
# 16       2516        112   0.230581
# 17       2614        110     0.2176
# 18       2344         85   0.216316
# 19       2432         94   0.216495
#                  Input   A    C     G    T        Mu
# 12   HepG2 siControl-1  30  305  1212   41  0.236776
# 13   HepG2 siControl-2  38  359  1137   82  0.296411
# 14    HepG2 siALKBH7-1  59  483  1639   89  0.277974
# 15    HepG2 siALKBH7-2  32  381  1422   73  0.254717
# 16  HeLa o/e Control-1  60  582  2516  112  0.230581
# 17  HeLa o/e Control-2  58  559  2614  110    0.2176
# 18   HeLa o/e ALKBH7-1  52  510  2344   85  0.216316
# 19   HeLa o/e ALKBH7-2  46  532  2432   94  0.216495
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Arg
# [  mt-Arg Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      10414       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        207        227
# 2    NaN        NaN        NaN   HepG2 siControl-2        234        200
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        382        287
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        358        276
# 5    NaN        NaN        NaN  HeLa o/e Control-1        156         98
# 6    NaN        NaN        NaN  HeLa o/e Control-2        162        120
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        134         86
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        160         87
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        151       1490   0.900241
# 2        137       1586   0.891516
# 3        249       2299   0.881256
# 4        222       2271   0.885513
# 5        101        899   0.875598
# 6        128        926   0.878743
# 7         80        695   0.865327
# 8         79        737   0.849483  ,    mt-Arg Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10    NaN      10421      m1A16                 NaN          A          C
# 11    NaN          +        NaN   HepG2 siControl-1       2775         25
# 12    NaN        NaN        NaN   HepG2 siControl-2       2778         26
# 13    NaN        NaN        NaN    HepG2 siALKBH7-1       4325         43
# 14    NaN        NaN        NaN    HepG2 siALKBH7-2       4203         23
# 15    NaN        NaN        NaN  HeLa o/e Control-1       1662          8
# 16    NaN        NaN        NaN  HeLa o/e Control-2       1752         11
# 17    NaN        NaN        NaN   HeLa o/e ALKBH7-1       1259          5
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-2       1286          1
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11         84         97   0.069104
# 12         86         96   0.069658
# 13        140        170    0.07546
# 14        128        184   0.073821
# 15         28         20   0.032596
# 16         25         29   0.035773
# 17         14         16   0.027048
# 18         22         22   0.033809  ]
#   mt-Arg Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      10414       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        207        227
# 2    NaN        NaN        NaN   HepG2 siControl-2        234        200
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        382        287
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        358        276
# 5    NaN        NaN        NaN  HeLa o/e Control-1        156         98
# 6    NaN        NaN        NaN  HeLa o/e Control-2        162        120
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        134         86
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        160         87
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        151       1490   0.900241
# 2        137       1586   0.891516
# 3        249       2299   0.881256
# 4        222       2271   0.885513
# 5        101        899   0.875598
# 6        128        926   0.878743
# 7         80        695   0.865327
# 8         79        737   0.849483
#                 Input    A    C    G     T        Mu
# 1   HepG2 siControl-1  207  227  151  1490  0.900241
# 2   HepG2 siControl-2  234  200  137  1586  0.891516
# 3    HepG2 siALKBH7-1  382  287  249  2299  0.881256
# 4    HepG2 siALKBH7-2  358  276  222  2271  0.885513
# 5  HeLa o/e Control-1  156   98  101   899  0.875598
# 6  HeLa o/e Control-2  162  120  128   926  0.878743
# 7   HeLa o/e ALKBH7-1  134   86   80   695  0.865327
# 8   HeLa o/e ALKBH7-2  160   87   79   737  0.849483
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#    mt-Arg Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10    NaN      10421      m1A16                 NaN          A          C
# 11    NaN          +        NaN   HepG2 siControl-1       2775         25
# 12    NaN        NaN        NaN   HepG2 siControl-2       2778         26
# 13    NaN        NaN        NaN    HepG2 siALKBH7-1       4325         43
# 14    NaN        NaN        NaN    HepG2 siALKBH7-2       4203         23
# 15    NaN        NaN        NaN  HeLa o/e Control-1       1662          8
# 16    NaN        NaN        NaN  HeLa o/e Control-2       1752         11
# 17    NaN        NaN        NaN   HeLa o/e ALKBH7-1       1259          5
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-2       1286          1
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11         84         97   0.069104
# 12         86         96   0.069658
# 13        140        170    0.07546
# 14        128        184   0.073821
# 15         28         20   0.032596
# 16         25         29   0.035773
# 17         14         16   0.027048
# 18         22         22   0.033809
#                  Input     A   C    G    T        Mu
# 11   HepG2 siControl-1  2775  25   84   97  0.069104
# 12   HepG2 siControl-2  2778  26   86   96  0.069658
# 13    HepG2 siALKBH7-1  4325  43  140  170   0.07546
# 14    HepG2 siALKBH7-2  4203  23  128  184  0.073821
# 15  HeLa o/e Control-1  1662   8   28   20  0.032596
# 16  HeLa o/e Control-2  1752  11   25   29  0.035773
# 17   HeLa o/e ALKBH7-1  1259   5   14   16  0.027048
# 18   HeLa o/e ALKBH7-2  1286   1   22   22  0.033809
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Asp
# [  mt-Asp Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       7527       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        171        105
# 2    NaN        NaN        NaN   HepG2 siControl-2        234         99
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        307        122
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        248        109
# 5    NaN        NaN        NaN  HeLa o/e Control-1        118        110
# 6    NaN        NaN        NaN  HeLa o/e Control-2        152         82
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        140         85
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        128         81
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        117       1086   0.884381
# 2        143       1260   0.865207
# 3        178       1689   0.866289
# 4        141       1287   0.861064
# 5         62        686   0.879098
# 6         62        761   0.856197
# 7         63        697   0.857868
# 8         62        628    0.85762  ]
#   mt-Asp Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       7527       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        171        105
# 2    NaN        NaN        NaN   HepG2 siControl-2        234         99
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        307        122
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        248        109
# 5    NaN        NaN        NaN  HeLa o/e Control-1        118        110
# 6    NaN        NaN        NaN  HeLa o/e Control-2        152         82
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        140         85
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        128         81
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        117       1086   0.884381
# 2        143       1260   0.865207
# 3        178       1689   0.866289
# 4        141       1287   0.861064
# 5         62        686   0.879098
# 6         62        761   0.856197
# 7         63        697   0.857868
# 8         62        628    0.85762
#                 Input    A    C    G     T        Mu
# 1   HepG2 siControl-1  171  105  117  1086  0.884381
# 2   HepG2 siControl-2  234   99  143  1260  0.865207
# 3    HepG2 siALKBH7-1  307  122  178  1689  0.866289
# 4    HepG2 siALKBH7-2  248  109  141  1287  0.861064
# 5  HeLa o/e Control-1  118  110   62   686  0.879098
# 6  HeLa o/e Control-2  152   82   62   761  0.856197
# 7   HeLa o/e ALKBH7-1  140   85   63   697  0.857868
# 8   HeLa o/e ALKBH7-2  128   81   62   628   0.85762
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Lys
# [  mt-Lys Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       8304       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1       3387       1152
# 2    NaN        NaN        NaN   HepG2 siControl-2       2861        872
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       4414       1400
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       2914        973
# 5    NaN        NaN        NaN  HeLa o/e Control-1       1234        395
# 6    NaN        NaN        NaN  HeLa o/e Control-2       1329        431
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1       1174        386
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2       1292        404
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1       1401       6511   0.727974
# 2       1161       5996   0.737282
# 3       1802       8717    0.72975
# 4       1188       6447   0.747093
# 5        580       2735   0.750405
# 6        680       2882   0.750282
# 7        572       2506   0.746874
# 8        569       2561   0.732283  ,    mt-Lys Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10   chrM       8349      m1A58                 NaN          A          C
# 11    NaN          +        NaN   HepG2 siControl-1       9164         68
# 12    NaN        NaN        NaN   HepG2 siControl-2       7514         71
# 13    NaN        NaN        NaN    HepG2 siALKBH7-1       8886         97
# 14    NaN        NaN        NaN    HepG2 siALKBH7-2       8451        108
# 15    NaN        NaN        NaN  HeLa o/e Control-1       3412         23
# 16    NaN        NaN        NaN  HeLa o/e Control-2       3648         36
# 17    NaN        NaN        NaN   HeLa o/e ALKBH7-1       3363         18
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-2       3356         25
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11        539        513   0.108907
# 12        462        415    0.11203
# 13        670        626   0.135519
# 14        561        598   0.130377
# 15        196        178   0.104227
# 16        222        183    0.10785
# 17        179        174   0.099357
# 18        179        192   0.105544  ]
#   mt-Lys Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       8304       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1       3387       1152
# 2    NaN        NaN        NaN   HepG2 siControl-2       2861        872
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       4414       1400
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       2914        973
# 5    NaN        NaN        NaN  HeLa o/e Control-1       1234        395
# 6    NaN        NaN        NaN  HeLa o/e Control-2       1329        431
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1       1174        386
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2       1292        404
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1       1401       6511   0.727974
# 2       1161       5996   0.737282
# 3       1802       8717    0.72975
# 4       1188       6447   0.747093
# 5        580       2735   0.750405
# 6        680       2882   0.750282
# 7        572       2506   0.746874
# 8        569       2561   0.732283
#                 Input     A     C     G     T        Mu
# 1   HepG2 siControl-1  3387  1152  1401  6511  0.727974
# 2   HepG2 siControl-2  2861   872  1161  5996  0.737282
# 3    HepG2 siALKBH7-1  4414  1400  1802  8717   0.72975
# 4    HepG2 siALKBH7-2  2914   973  1188  6447  0.747093
# 5  HeLa o/e Control-1  1234   395   580  2735  0.750405
# 6  HeLa o/e Control-2  1329   431   680  2882  0.750282
# 7   HeLa o/e ALKBH7-1  1174   386   572  2506  0.746874
# 8   HeLa o/e ALKBH7-2  1292   404   569  2561  0.732283
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#    mt-Lys Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10   chrM       8349      m1A58                 NaN          A          C
# 11    NaN          +        NaN   HepG2 siControl-1       9164         68
# 12    NaN        NaN        NaN   HepG2 siControl-2       7514         71
# 13    NaN        NaN        NaN    HepG2 siALKBH7-1       8886         97
# 14    NaN        NaN        NaN    HepG2 siALKBH7-2       8451        108
# 15    NaN        NaN        NaN  HeLa o/e Control-1       3412         23
# 16    NaN        NaN        NaN  HeLa o/e Control-2       3648         36
# 17    NaN        NaN        NaN   HeLa o/e ALKBH7-1       3363         18
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-2       3356         25
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11        539        513   0.108907
# 12        462        415    0.11203
# 13        670        626   0.135519
# 14        561        598   0.130377
# 15        196        178   0.104227
# 16        222        183    0.10785
# 17        179        174   0.099357
# 18        179        192   0.105544
#                  Input     A    C    G    T        Mu
# 11   HepG2 siControl-1  9164   68  539  513  0.108907
# 12   HepG2 siControl-2  7514   71  462  415   0.11203
# 13    HepG2 siALKBH7-1  8886   97  670  626  0.135519
# 14    HepG2 siALKBH7-2  8451  108  561  598  0.130377
# 15  HeLa o/e Control-1  3412   23  196  178  0.104227
# 16  HeLa o/e Control-2  3648   36  222  183   0.10785
# 17   HeLa o/e ALKBH7-1  3363   18  179  174  0.099357
# 18   HeLa o/e ALKBH7-2  3356   25  179  192  0.105544
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Leu1(CUN)
# [  mt-Leu1 Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    chrM      12275       m1A9                 NaN          A          C
# 1     NaN          +        NaN   HepG2 siControl-1       1314        304
# 2     NaN        NaN        NaN   HepG2 siControl-2       1435        348
# 3     NaN        NaN        NaN    HepG2 siALKBH7-1       1906        444
# 4     NaN        NaN        NaN    HepG2 siALKBH7-2       1674        353
# 5     NaN        NaN        NaN  HeLa o/e Control-1        832        202
# 6     NaN        NaN        NaN  HeLa o/e Control-2        797        235
# 7     NaN        NaN        NaN   HeLa o/e ALKBH7-1        744        202
# 8     NaN        NaN        NaN   HeLa o/e ALKBH7-2        807        213
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        546       2450   0.715215
# 2        556       2503   0.703635
# 3        717       3469   0.708384
# 4        655       2972   0.703926
# 5        447       2015   0.762014
# 6        463       2012    0.77274
# 7        423       1825   0.767063
# 8        474       1939   0.764929  ,    mt-Leu1 Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10    chrM      12302      m1G37                 NaN          A          C
# 11     NaN          +        NaN   HepG2 siControl-1         90       1854
# 12     NaN        NaN        NaN   HepG2 siControl-2        101       1616
# 13     NaN        NaN        NaN    HepG2 siALKBH7-1        121       2491
# 14     NaN        NaN        NaN    HepG2 siALKBH7-2         98       2263
# 15     NaN        NaN        NaN  HeLa o/e Control-1         47        684
# 16     NaN        NaN        NaN  HeLa o/e Control-2         45        728
# 17     NaN        NaN        NaN   HeLa o/e ALKBH7-1         51        695
# 18     NaN        NaN        NaN   HeLa o/e ALKBH7-2         49        683
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11       8356        264   0.209012
# 12       8664        278   0.187166
# 13      10639        386   0.219843
# 14      10038        316   0.210539
# 15       3177        167   0.220368
# 16       3440        183    0.21747
# 17       3157        162    0.22337
# 18       3268        172   0.216683  ]
#   mt-Leu1 Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    chrM      12275       m1A9                 NaN          A          C
# 1     NaN          +        NaN   HepG2 siControl-1       1314        304
# 2     NaN        NaN        NaN   HepG2 siControl-2       1435        348
# 3     NaN        NaN        NaN    HepG2 siALKBH7-1       1906        444
# 4     NaN        NaN        NaN    HepG2 siALKBH7-2       1674        353
# 5     NaN        NaN        NaN  HeLa o/e Control-1        832        202
# 6     NaN        NaN        NaN  HeLa o/e Control-2        797        235
# 7     NaN        NaN        NaN   HeLa o/e ALKBH7-1        744        202
# 8     NaN        NaN        NaN   HeLa o/e ALKBH7-2        807        213
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        546       2450   0.715215
# 2        556       2503   0.703635
# 3        717       3469   0.708384
# 4        655       2972   0.703926
# 5        447       2015   0.762014
# 6        463       2012    0.77274
# 7        423       1825   0.767063
# 8        474       1939   0.764929
#                 Input     A    C    G     T        Mu
# 1   HepG2 siControl-1  1314  304  546  2450  0.715215
# 2   HepG2 siControl-2  1435  348  556  2503  0.703635
# 3    HepG2 siALKBH7-1  1906  444  717  3469  0.708384
# 4    HepG2 siALKBH7-2  1674  353  655  2972  0.703926
# 5  HeLa o/e Control-1   832  202  447  2015  0.762014
# 6  HeLa o/e Control-2   797  235  463  2012   0.77274
# 7   HeLa o/e ALKBH7-1   744  202  423  1825  0.767063
# 8   HeLa o/e ALKBH7-2   807  213  474  1939  0.764929
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#    mt-Leu1 Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10    chrM      12302      m1G37                 NaN          A          C
# 11     NaN          +        NaN   HepG2 siControl-1         90       1854
# 12     NaN        NaN        NaN   HepG2 siControl-2        101       1616
# 13     NaN        NaN        NaN    HepG2 siALKBH7-1        121       2491
# 14     NaN        NaN        NaN    HepG2 siALKBH7-2         98       2263
# 15     NaN        NaN        NaN  HeLa o/e Control-1         47        684
# 16     NaN        NaN        NaN  HeLa o/e Control-2         45        728
# 17     NaN        NaN        NaN   HeLa o/e ALKBH7-1         51        695
# 18     NaN        NaN        NaN   HeLa o/e ALKBH7-2         49        683
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11       8356        264   0.209012
# 12       8664        278   0.187166
# 13      10639        386   0.219843
# 14      10038        316   0.210539
# 15       3177        167   0.220368
# 16       3440        183    0.21747
# 17       3157        162    0.22337
# 18       3268        172   0.216683
#                  Input    A     C      G    T        Mu
# 11   HepG2 siControl-1   90  1854   8356  264  0.209012
# 12   HepG2 siControl-2  101  1616   8664  278  0.187166
# 13    HepG2 siALKBH7-1  121  2491  10639  386  0.219843
# 14    HepG2 siALKBH7-2   98  2263  10038  316  0.210539
# 15  HeLa o/e Control-1   47   684   3177  167  0.220368
# 16  HeLa o/e Control-2   45   728   3440  183   0.21747
# 17   HeLa o/e ALKBH7-1   51   695   3157  162   0.22337
# 18   HeLa o/e ALKBH7-2   49   683   3268  172  0.216683
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Trp
# [  mt-Trp Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       5521       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        556        240
# 2    NaN        NaN        NaN   HepG2 siControl-2        657        321
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        864        372
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        725        276
# 5    NaN        NaN        NaN  HeLa o/e Control-1        388        194
# 6    NaN        NaN        NaN  HeLa o/e Control-2        379        196
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        335        143
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        340        159
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        220       2752   0.852442
# 2        252       3392   0.857854
# 3        359       4182   0.850441
# 4        277       3121    0.83519
# 5        211       2578   0.884901
# 6        225       2754    0.89336
# 7        172       2378   0.889366
# 8        211       2422   0.891443  ]
#   mt-Trp Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       5521       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        556        240
# 2    NaN        NaN        NaN   HepG2 siControl-2        657        321
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        864        372
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        725        276
# 5    NaN        NaN        NaN  HeLa o/e Control-1        388        194
# 6    NaN        NaN        NaN  HeLa o/e Control-2        379        196
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        335        143
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        340        159
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        220       2752   0.852442
# 2        252       3392   0.857854
# 3        359       4182   0.850441
# 4        277       3121    0.83519
# 5        211       2578   0.884901
# 6        225       2754    0.89336
# 7        172       2378   0.889366
# 8        211       2422   0.891443
#                 Input    A    C    G     T        Mu
# 1   HepG2 siControl-1  556  240  220  2752  0.852442
# 2   HepG2 siControl-2  657  321  252  3392  0.857854
# 3    HepG2 siALKBH7-1  864  372  359  4182  0.850441
# 4    HepG2 siALKBH7-2  725  276  277  3121   0.83519
# 5  HeLa o/e Control-1  388  194  211  2578  0.884901
# 6  HeLa o/e Control-2  379  196  225  2754   0.89336
# 7   HeLa o/e ALKBH7-1  335  143  172  2378  0.889366
# 8   HeLa o/e ALKBH7-2  340  159  211  2422  0.891443
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# His
# [  mt-His Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      12147       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        351        274
# 2    NaN        NaN        NaN   HepG2 siControl-2        404        267
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        468        367
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        453        300
# 5    NaN        NaN        NaN  HeLa o/e Control-1        202        129
# 6    NaN        NaN        NaN  HeLa o/e Control-2        190        146
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        190        145
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        202        169
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        170       2622   0.897278
# 2        177       2838   0.890396
# 3        267       3548   0.899355
# 4        223       3239   0.892527
# 5         90       1203   0.875616
# 6        123       1336    0.89415
# 7         83       1169   0.880277
# 8        103       1196   0.879042  ]
#   mt-His Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      12147       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        351        274
# 2    NaN        NaN        NaN   HepG2 siControl-2        404        267
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        468        367
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        453        300
# 5    NaN        NaN        NaN  HeLa o/e Control-1        202        129
# 6    NaN        NaN        NaN  HeLa o/e Control-2        190        146
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        190        145
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        202        169
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        170       2622   0.897278
# 2        177       2838   0.890396
# 3        267       3548   0.899355
# 4        223       3239   0.892527
# 5         90       1203   0.875616
# 6        123       1336    0.89415
# 7         83       1169   0.880277
# 8        103       1196   0.879042
#                 Input    A    C    G     T        Mu
# 1   HepG2 siControl-1  351  274  170  2622  0.897278
# 2   HepG2 siControl-2  404  267  177  2838  0.890396
# 3    HepG2 siALKBH7-1  468  367  267  3548  0.899355
# 4    HepG2 siALKBH7-2  453  300  223  3239  0.892527
# 5  HeLa o/e Control-1  202  129   90  1203  0.875616
# 6  HeLa o/e Control-2  190  146  123  1336   0.89415
# 7   HeLa o/e ALKBH7-1  190  145   83  1169  0.880277
# 8   HeLa o/e ALKBH7-2  202  169  103  1196  0.879042
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Phe
# [  mt-Phe Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM        587       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1       1607        925
# 2    NaN        NaN        NaN   HepG2 siControl-2       1351        741
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       1806        916
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       1625        848
# 5    NaN        NaN        NaN  HeLa o/e Control-1        613        506
# 6    NaN        NaN        NaN  HeLa o/e Control-2        626        496
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        573        417
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        567        424
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1       1402       6182   0.841143
# 2       1108       5490   0.844534
# 3       1403       7455   0.844041
# 4       1253       6261   0.837288
# 5        536       3942   0.890477
# 6        565       4085   0.891545
# 7        492       3422   0.883157
# 8        458       3507   0.885593  ]
#   mt-Phe Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM        587       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1       1607        925
# 2    NaN        NaN        NaN   HepG2 siControl-2       1351        741
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       1806        916
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       1625        848
# 5    NaN        NaN        NaN  HeLa o/e Control-1        613        506
# 6    NaN        NaN        NaN  HeLa o/e Control-2        626        496
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        573        417
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        567        424
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1       1402       6182   0.841143
# 2       1108       5490   0.844534
# 3       1403       7455   0.844041
# 4       1253       6261   0.837288
# 5        536       3942   0.890477
# 6        565       4085   0.891545
# 7        492       3422   0.883157
# 8        458       3507   0.885593
#                 Input     A    C     G     T        Mu
# 1   HepG2 siControl-1  1607  925  1402  6182  0.841143
# 2   HepG2 siControl-2  1351  741  1108  5490  0.844534
# 3    HepG2 siALKBH7-1  1806  916  1403  7455  0.844041
# 4    HepG2 siALKBH7-2  1625  848  1253  6261  0.837288
# 5  HeLa o/e Control-1   613  506   536  3942  0.890477
# 6  HeLa o/e Control-2   626  496   565  4085  0.891545
# 7   HeLa o/e ALKBH7-1   573  417   492  3422  0.883157
# 8   HeLa o/e ALKBH7-2   567  424   458  3507  0.885593
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Gly
# [  mt-Gly Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      10000       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        362        255
# 2    NaN        NaN        NaN   HepG2 siControl-2        421        236
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        537        300
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        448        276
# 5    NaN        NaN        NaN  HeLa o/e Control-1        280        112
# 6    NaN        NaN        NaN  HeLa o/e Control-2        313        137
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        264        109
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        242        106
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        410       1836   0.873559
# 2        428       1883   0.858154
# 3        521       2505   0.860989
# 4        475       2071   0.862997
# 5        179       1143   0.836639
# 6        211       1224   0.833952
# 7        190        964   0.827112
# 8        172       1029    0.84377  ]
#   mt-Gly Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      10000       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        362        255
# 2    NaN        NaN        NaN   HepG2 siControl-2        421        236
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        537        300
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        448        276
# 5    NaN        NaN        NaN  HeLa o/e Control-1        280        112
# 6    NaN        NaN        NaN  HeLa o/e Control-2        313        137
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        264        109
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        242        106
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        410       1836   0.873559
# 2        428       1883   0.858154
# 3        521       2505   0.860989
# 4        475       2071   0.862997
# 5        179       1143   0.836639
# 6        211       1224   0.833952
# 7        190        964   0.827112
# 8        172       1029    0.84377
#                 Input    A    C    G     T        Mu
# 1   HepG2 siControl-1  362  255  410  1836  0.873559
# 2   HepG2 siControl-2  421  236  428  1883  0.858154
# 3    HepG2 siALKBH7-1  537  300  521  2505  0.860989
# 4    HepG2 siALKBH7-2  448  276  475  2071  0.862997
# 5  HeLa o/e Control-1  280  112  179  1143  0.836639
# 6  HeLa o/e Control-2  313  137  211  1224  0.833952
# 7   HeLa o/e ALKBH7-1  264  109  190   964  0.827112
# 8   HeLa o/e ALKBH7-2  242  106  172  1029   0.84377
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Val
# [  mt-Val Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       1612       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1       6245       3893
# 2    NaN        NaN        NaN   HepG2 siControl-2       4668       2780
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       7048       4209
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       5714       3446
# 5    NaN        NaN        NaN  HeLa o/e Control-1        951        589
# 6    NaN        NaN        NaN  HeLa o/e Control-2       1002        655
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        892        588
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        905        566
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1       3559      21418   0.822156
# 2       2624      16037   0.821211
# 3       4143      23943   0.820858
# 4       3100      18928   0.816789
# 5        661       5216   0.871781
# 6        751       5577   0.874515
# 7        658       4624   0.868086
# 8        672       4960   0.872589  ]
#   mt-Val Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       1612       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1       6245       3893
# 2    NaN        NaN        NaN   HepG2 siControl-2       4668       2780
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       7048       4209
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       5714       3446
# 5    NaN        NaN        NaN  HeLa o/e Control-1        951        589
# 6    NaN        NaN        NaN  HeLa o/e Control-2       1002        655
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        892        588
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        905        566
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1       3559      21418   0.822156
# 2       2624      16037   0.821211
# 3       4143      23943   0.820858
# 4       3100      18928   0.816789
# 5        661       5216   0.871781
# 6        751       5577   0.874515
# 7        658       4624   0.868086
# 8        672       4960   0.872589
#                 Input     A     C     G      T        Mu
# 1   HepG2 siControl-1  6245  3893  3559  21418  0.822156
# 2   HepG2 siControl-2  4668  2780  2624  16037  0.821211
# 3    HepG2 siALKBH7-1  7048  4209  4143  23943  0.820858
# 4    HepG2 siALKBH7-2  5714  3446  3100  18928  0.816789
# 5  HeLa o/e Control-1   951   589   661   5216  0.871781
# 6  HeLa o/e Control-2  1002   655   751   5577  0.874515
# 7   HeLa o/e ALKBH7-1   892   588   658   4624  0.868086
# 8   HeLa o/e ALKBH7-2   905   566   672   4960  0.872589
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Thr
# [  mt-Thr Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      15897       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        476        139
# 2    NaN        NaN        NaN   HepG2 siControl-2        419        138
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        584        177
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        476        139
# 5    NaN        NaN        NaN  HeLa o/e Control-1        341        175
# 6    NaN        NaN        NaN  HeLa o/e Control-2        378        172
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        294        161
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        347        156
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        345       3322   0.888837
# 2        299       2923   0.889124
# 3        396       3856   0.883503
# 4        370       3330   0.889687
# 5        311       2680   0.902766
# 6        306       2941   0.900448
# 7        284       2503   0.909315
# 8        257       2529   0.894497  ,    mt-Thr Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10   chrM      15918      m3C32                 NaN          A          C
# 11    NaN          +        NaN   HepG2 siControl-1        423       1477
# 12    NaN        NaN        NaN   HepG2 siControl-2        404       1196
# 13    NaN        NaN        NaN    HepG2 siALKBH7-1        462       1466
# 14    NaN        NaN        NaN    HepG2 siALKBH7-2        409       1402
# 15    NaN        NaN        NaN  HeLa o/e Control-1        154        927
# 16    NaN        NaN        NaN  HeLa o/e Control-2        207       1044
# 17    NaN        NaN        NaN   HeLa o/e ALKBH7-1        169        835
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-2        178        917
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11        199       3369   0.729883
# 12        179       3393   0.768755
# 13        229       4231   0.770507
# 14        206       3766   0.757565
# 15         94       1725   0.680345
# 16         83       1847   0.671801
# 17         90       1537    0.68263
# 18         90       1596   0.670262  ]
#   mt-Thr Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      15897       m1A9                 NaN          A          C
# 1    NaN          +        NaN   HepG2 siControl-1        476        139
# 2    NaN        NaN        NaN   HepG2 siControl-2        419        138
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        584        177
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        476        139
# 5    NaN        NaN        NaN  HeLa o/e Control-1        341        175
# 6    NaN        NaN        NaN  HeLa o/e Control-2        378        172
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        294        161
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        347        156
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        345       3322   0.888837
# 2        299       2923   0.889124
# 3        396       3856   0.883503
# 4        370       3330   0.889687
# 5        311       2680   0.902766
# 6        306       2941   0.900448
# 7        284       2503   0.909315
# 8        257       2529   0.894497
#                 Input    A    C    G     T        Mu
# 1   HepG2 siControl-1  476  139  345  3322  0.888837
# 2   HepG2 siControl-2  419  138  299  2923  0.889124
# 3    HepG2 siALKBH7-1  584  177  396  3856  0.883503
# 4    HepG2 siALKBH7-2  476  139  370  3330  0.889687
# 5  HeLa o/e Control-1  341  175  311  2680  0.902766
# 6  HeLa o/e Control-2  378  172  306  2941  0.900448
# 7   HeLa o/e ALKBH7-1  294  161  284  2503  0.909315
# 8   HeLa o/e ALKBH7-2  347  156  257  2529  0.894497
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#    mt-Thr Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10   chrM      15918      m3C32                 NaN          A          C
# 11    NaN          +        NaN   HepG2 siControl-1        423       1477
# 12    NaN        NaN        NaN   HepG2 siControl-2        404       1196
# 13    NaN        NaN        NaN    HepG2 siALKBH7-1        462       1466
# 14    NaN        NaN        NaN    HepG2 siALKBH7-2        409       1402
# 15    NaN        NaN        NaN  HeLa o/e Control-1        154        927
# 16    NaN        NaN        NaN  HeLa o/e Control-2        207       1044
# 17    NaN        NaN        NaN   HeLa o/e ALKBH7-1        169        835
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-2        178        917
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11        199       3369   0.729883
# 12        179       3393   0.768755
# 13        229       4231   0.770507
# 14        206       3766   0.757565
# 15         94       1725   0.680345
# 16         83       1847   0.671801
# 17         90       1537    0.68263
# 18         90       1596   0.670262
#                  Input    A     C    G     T        Mu
# 11   HepG2 siControl-1  423  1477  199  3369  0.729883
# 12   HepG2 siControl-2  404  1196  179  3393  0.768755
# 13    HepG2 siALKBH7-1  462  1466  229  4231  0.770507
# 14    HepG2 siALKBH7-2  409  1402  206  3766  0.757565
# 15  HeLa o/e Control-1  154   927   94  1725  0.680345
# 16  HeLa o/e Control-2  207  1044   83  1847  0.671801
# 17   HeLa o/e ALKBH7-1  169   835   90  1537   0.68263
# 18   HeLa o/e ALKBH7-2  178   917   90  1596  0.670262
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Leu2(UUR)
# [  mt-Leu2 Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    chrM       3290      m1A58                 NaN          A          C
# 1     NaN          +        NaN   HepG2 siControl-1        751        276
# 2     NaN        NaN        NaN   HepG2 siControl-2        617        235
# 3     NaN        NaN        NaN    HepG2 siALKBH7-1        752        310
# 4     NaN        NaN        NaN    HepG2 siALKBH7-2        740        299
# ...
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       2588        473
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       2061        400
# 5    NaN        NaN        NaN  HeLa o/e Control-1       1153        248
# 6    NaN        NaN        NaN  HeLa o/e Control-2       1134        240
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1       1059        252
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2       1138        249
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        470       2689   0.661043
# 2        451       2782   0.677499
# 3        745       4268   0.679465
# 4        581       3579   0.688718
# 5        358       2229   0.710883
# 6        351       2493   0.731152
# 7        323       2180   0.722339
# 8        327       2353   0.720187
#                 Input     A    C    G     T        Mu
# 1   HepG2 siControl-1  1768  289  470  2689  0.661043
# 2   HepG2 siControl-2  1707  353  451  2782  0.677499
# 3    HepG2 siALKBH7-1  2588  473  745  4268  0.679465
# 4    HepG2 siALKBH7-2  2061  400  581  3579  0.688718
# 5  HeLa o/e Control-1  1153  248  358  2229  0.710883
# 6  HeLa o/e Control-2  1134  240  351  2493  0.731152
# 7   HeLa o/e ALKBH7-1  1059  252  323  2180  0.722339
# 8   HeLa o/e ALKBH7-2  1138  249  327  2353  0.720187
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Gln
# [  mt-Gln Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       4393       m1G9                 NaN          A          C
# 1    NaN          -        NaN   HepG2 siControl-1        217        344
# 2    NaN        NaN        NaN   HepG2 siControl-2        216        368
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        306        525
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        269        429
# 5    NaN        NaN        NaN  HeLa o/e Control-1        132        292
# 6    NaN        NaN        NaN  HeLa o/e Control-2        142        319
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        112        269
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        136        299
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1       3035        966   0.334722
# 2       3401       1052   0.324797
# 3       5005       1589   0.325926
# 4       4081       1264   0.324673
# 5       1489        562   0.398384
# 6       1605        651   0.409275
# 7       1470        570   0.392813
# 8       1483        623   0.416372  ,    mt-Gln Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10   chrM       4365      m1G37                 NaN          A          C
# 11    NaN          -        NaN   HepG2 siControl-1        553       1037
# 12    NaN        NaN        NaN   HepG2 siControl-2        583       1197
# 13    NaN        NaN        NaN    HepG2 siALKBH7-1        837       1471
# 14    NaN        NaN        NaN    HepG2 siALKBH7-2        712       1265
# 15    NaN        NaN        NaN  HeLa o/e Control-1        327        467
# 16    NaN        NaN        NaN  HeLa o/e Control-2        321        505
# 17    NaN        NaN        NaN   HeLa o/e ALKBH7-1        311        457
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-2        270        462
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11       2932       1505   0.513522
# 12       3020       1463   0.517803
# 13       4188       2206   0.518731
# 14       3606       1835   0.513885
# 15       1268        659   0.533995
# 16       1345        719   0.534602
# 17       1228        596   0.526235
# 18       1182        631    0.53556  ]
#   mt-Gln Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM       4393       m1G9                 NaN          A          C
# 1    NaN          -        NaN   HepG2 siControl-1        217        344
# 2    NaN        NaN        NaN   HepG2 siControl-2        216        368
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1        306        525
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2        269        429
# 5    NaN        NaN        NaN  HeLa o/e Control-1        132        292
# 6    NaN        NaN        NaN  HeLa o/e Control-2        142        319
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        112        269
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        136        299
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1       3035        966   0.334722
# 2       3401       1052   0.324797
# 3       5005       1589   0.325926
# 4       4081       1264   0.324673
# 5       1489        562   0.398384
# 6       1605        651   0.409275
# 7       1470        570   0.392813
# 8       1483        623   0.416372
#                 Input    A    C     G     T        Mu
# 1   HepG2 siControl-1  217  344  3035   966  0.334722
# 2   HepG2 siControl-2  216  368  3401  1052  0.324797
# 3    HepG2 siALKBH7-1  306  525  5005  1589  0.325926
# 4    HepG2 siALKBH7-2  269  429  4081  1264  0.324673
# 5  HeLa o/e Control-1  132  292  1489   562  0.398384
# 6  HeLa o/e Control-2  142  319  1605   651  0.409275
# 7   HeLa o/e ALKBH7-1  112  269  1470   570  0.392813
# 8   HeLa o/e ALKBH7-2  136  299  1483   623  0.416372
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#    mt-Gln Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10   chrM       4365      m1G37                 NaN          A          C
# 11    NaN          -        NaN   HepG2 siControl-1        553       1037
# 12    NaN        NaN        NaN   HepG2 siControl-2        583       1197
# 13    NaN        NaN        NaN    HepG2 siALKBH7-1        837       1471
# 14    NaN        NaN        NaN    HepG2 siALKBH7-2        712       1265
# 15    NaN        NaN        NaN  HeLa o/e Control-1        327        467
# 16    NaN        NaN        NaN  HeLa o/e Control-2        321        505
# 17    NaN        NaN        NaN   HeLa o/e ALKBH7-1        311        457
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-2        270        462
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11       2932       1505   0.513522
# 12       3020       1463   0.517803
# 13       4188       2206   0.518731
# 14       3606       1835   0.513885
# 15       1268        659   0.533995
# 16       1345        719   0.534602
# 17       1228        596   0.526235
# 18       1182        631    0.53556
#                  Input    A     C     G     T        Mu
# 11   HepG2 siControl-1  553  1037  2932  1505  0.513522
# 12   HepG2 siControl-2  583  1197  3020  1463  0.517803
# 13    HepG2 siALKBH7-1  837  1471  4188  2206  0.518731
# 14    HepG2 siALKBH7-2  712  1265  3606  1835  0.513885
# 15  HeLa o/e Control-1  327   467  1268   659  0.533995
# 16  HeLa o/e Control-2  321   505  1345   719  0.534602
# 17   HeLa o/e ALKBH7-1  311   457  1228   596  0.526235
# 18   HeLa o/e ALKBH7-2  270   462  1182   631   0.53556
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Glu
# [  mt-Glu Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      14735       m1A9                 NaN          A          C
# 1    NaN          -        NaN   HepG2 siControl-1       1057       1199
# 2    NaN        NaN        NaN   HepG2 siControl-2        931       1093
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       1344       1413
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       1243       1272
# 5    NaN        NaN        NaN  HeLa o/e Control-1        666        634
# 6    NaN        NaN        NaN  HeLa o/e Control-2        754        684
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        663        534
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        686        552
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        793       9976   0.918848
# 2        684       9038   0.920739
# 3       1006      11633   0.912705
# 4        954      10993   0.914051
# 5        391       5694   0.909817
# 6        401       6021   0.904071
# 7        372       5187   0.901865
# 8        383       5301   0.900896  ]
#   mt-Glu Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      14735       m1A9                 NaN          A          C
# 1    NaN          -        NaN   HepG2 siControl-1       1057       1199
# 2    NaN        NaN        NaN   HepG2 siControl-2        931       1093
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       1344       1413
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       1243       1272
# 5    NaN        NaN        NaN  HeLa o/e Control-1        666        634
# 6    NaN        NaN        NaN  HeLa o/e Control-2        754        684
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        663        534
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        686        552
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        793       9976   0.918848
# 2        684       9038   0.920739
# 3       1006      11633   0.912705
# 4        954      10993   0.914051
# 5        391       5694   0.909817
# 6        401       6021   0.904071
# 7        372       5187   0.901865
# 8        383       5301   0.900896
#                 Input     A     C     G      T        Mu
# 1   HepG2 siControl-1  1057  1199   793   9976  0.918848
# 2   HepG2 siControl-2   931  1093   684   9038  0.920739
# 3    HepG2 siALKBH7-1  1344  1413  1006  11633  0.912705
# 4    HepG2 siALKBH7-2  1243  1272   954  10993  0.914051
# 5  HeLa o/e Control-1   666   634   391   5694  0.909817
# 6  HeLa o/e Control-2   754   684   401   6021  0.904071
# 7   HeLa o/e ALKBH7-1   663   534   372   5187  0.901865
# 8   HeLa o/e ALKBH7-2   686   552   383   5301  0.900896
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
# Pro
# [  mt-Pro Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      16016       m1A9                 NaN          A          C
# 1    NaN          -        NaN   HepG2 siControl-1        826        514
# 2    NaN        NaN        NaN   HepG2 siControl-2        922        475
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       1404        729
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       1014        628
# 5    NaN        NaN        NaN  HeLa o/e Control-1        643        355
# 6    NaN        NaN        NaN  HeLa o/e Control-2        699        367
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        616        290
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        639        344
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        469       4403   0.867032
# 2        463       4720   0.859878
# 3        731       7129   0.859502
# 4        580       5747   0.872757
# 5        144       3106   0.848635
# 6        172       3304   0.846103
# 7        146       2901   0.844169
# 8        169       2875   0.841321  ,    mt-Pro Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10   chrM      15990      m1G37                 NaN          A          C
# 11    NaN          -        NaN   HepG2 siControl-1        389       2885
# 12    NaN        NaN        NaN   HepG2 siControl-2        363       2983
# 13    NaN        NaN        NaN    HepG2 siALKBH7-1        585       3987
# 14    NaN        NaN        NaN    HepG2 siALKBH7-2        483       3654
# 15    NaN        NaN        NaN  HeLa o/e Control-1        269       1852
# 16    NaN        NaN        NaN  HeLa o/e Control-2        312       2060
# 17    NaN        NaN        NaN   HeLa o/e ALKBH7-1        301       1832
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-2        313       1920
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11       6272       1098   0.410748
# 12       6627       1148     0.4041
# 13       8838       1700   0.415089
# 14       7924       1379   0.410417
# 15       4951       1022   0.388312
# 16       5442       1144   0.392498
# 17       5047       1066   0.387946
# 18       5152       1058    0.38979  ]
#   mt-Pro Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0   chrM      16016       m1A9                 NaN          A          C
# 1    NaN          -        NaN   HepG2 siControl-1        826        514
# 2    NaN        NaN        NaN   HepG2 siControl-2        922        475
# 3    NaN        NaN        NaN    HepG2 siALKBH7-1       1404        729
# 4    NaN        NaN        NaN    HepG2 siALKBH7-2       1014        628
# 5    NaN        NaN        NaN  HeLa o/e Control-1        643        355
# 6    NaN        NaN        NaN  HeLa o/e Control-2        699        367
# 7    NaN        NaN        NaN   HeLa o/e ALKBH7-1        616        290
# 8    NaN        NaN        NaN   HeLa o/e ALKBH7-2        639        344
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          G          T         Mu
# 1        469       4403   0.867032
# 2        463       4720   0.859878
# 3        731       7129   0.859502
# 4        580       5747   0.872757
# 5        144       3106   0.848635
# 6        172       3304   0.846103
# 7        146       2901   0.844169
# 8        169       2875   0.841321
#                 Input     A    C    G     T        Mu
# 1   HepG2 siControl-1   826  514  469  4403  0.867032
# 2   HepG2 siControl-2   922  475  463  4720  0.859878
# 3    HepG2 siALKBH7-1  1404  729  731  7129  0.859502
# 4    HepG2 siALKBH7-2  1014  628  580  5747  0.872757
# 5  HeLa o/e Control-1   643  355  144  3106  0.848635
# 6  HeLa o/e Control-2   699  367  172  3304  0.846103
# 7   HeLa o/e ALKBH7-1   616  290  146  2901  0.844169
# 8   HeLa o/e ALKBH7-2   639  344  169  2875  0.841321
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
#    mt-Pro Unnamed: 1 Unnamed: 2          Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 10   chrM      15990      m1G37                 NaN          A          C
# 11    NaN          -        NaN   HepG2 siControl-1        389       2885
# 12    NaN        NaN        NaN   HepG2 siControl-2        363       2983
# 13    NaN        NaN        NaN    HepG2 siALKBH7-1        585       3987
# 14    NaN        NaN        NaN    HepG2 siALKBH7-2        483       3654
# 15    NaN        NaN        NaN  HeLa o/e Control-1        269       1852
# 16    NaN        NaN        NaN  HeLa o/e Control-2        312       2060
# 17    NaN        NaN        NaN   HeLa o/e ALKBH7-1        301       1832
# 18    NaN        NaN        NaN   HeLa o/e ALKBH7-2        313       1920
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8
# 10          G          T         Mu
# 11       6272       1098   0.410748
# 12       6627       1148     0.4041
# 13       8838       1700   0.415089
# 14       7924       1379   0.410417
# 15       4951       1022   0.388312
# 16       5442       1144   0.392498
# 17       5047       1066   0.387946
# 18       5152       1058    0.38979
#                  Input    A     C     G     T        Mu
# 11   HepG2 siControl-1  389  2885  6272  1098  0.410748
# 12   HepG2 siControl-2  363  2983  6627  1148    0.4041
# 13    HepG2 siALKBH7-1  585  3987  8838  1700  0.415089
# 14    HepG2 siALKBH7-2  483  3654  7924  1379  0.410417
# 15  HeLa o/e Control-1  269  1852  4951  1022  0.388312
# 16  HeLa o/e Control-2  312  2060  5442  1144  0.392498
# 17   HeLa o/e ALKBH7-1  301  1832  5047  1066  0.387946
# 18   HeLa o/e ALKBH7-2  313  1920  5152  1058   0.38979
# HepG2siControl-1
# HepG2siControl-2
# HepG2siALKBH7-1
# HepG2siALKBH7-2
# HeLaoeControl-1
# HeLaoeControl-2
# HeLaoeALKBH7-1
# HeLaoeALKBH7-2
